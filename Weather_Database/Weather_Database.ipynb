# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc,                          
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 2 of Set 1 | masunga
# Processing Record 3 of Set 1 | saint-philippe
# Processing Record 4 of Set 1 | coihaique
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | codrington
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | lasa
# Processing Record 9 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 1 | victoria
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | chuy
# Processing Record 15 of Set 1 | torbay
# Processing Record 16 of Set 1 | nosy varika
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | san cristobal
# Processing Record 19 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 1 | richards bay
# Processing Record 22 of Set 1 | touros
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | paamiut
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | margate
# Processing Record 30 of Set 1 | tarnos
# Processing Record 31 of Set 1 | santa helena de goias
# Processing Record 32 of Set 1 | jujuy
# City not found. Skipping...
# Processing Record 33 of Set 1 | jalingo
# Processing Record 34 of Set 1 | tucuma
# Processing Record 35 of Set 1 | xuddur
# Processing Record 36 of Set 1 | kem
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | khipro
# Processing Record 39 of Set 1 | mercedes
# Processing Record 40 of Set 1 | sainte-maxime
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | nioaque
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | irtyshskiy
# Processing Record 47 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 1 | necochea
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | port alfred
# Processing Record 1 of Set 2 | jamestown
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | arona
# Processing Record 4 of Set 2 | keti bandar
# Processing Record 5 of Set 2 | kemijarvi
# Processing Record 6 of Set 2 | dharmadam
# Processing Record 7 of Set 2 | katakwi
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | arinos
# Processing Record 10 of Set 2 | harper
# Processing Record 11 of Set 2 | namibe
# Processing Record 12 of Set 2 | vangaindrano
# Processing Record 13 of Set 2 | pangnirtung
# Processing Record 14 of Set 2 | junin
# Processing Record 15 of Set 2 | placido de castro
# Processing Record 16 of Set 2 | corn island
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | umm kaddadah
# Processing Record 19 of Set 2 | yar-sale
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | thohoyandou
# Processing Record 23 of Set 2 | kaduqli
# Processing Record 24 of Set 2 | tarboro
# Processing Record 25 of Set 2 | bathsheba
# Processing Record 26 of Set 2 | vetapalem
# Processing Record 27 of Set 2 | chipinge
# Processing Record 28 of Set 2 | taybad
# Processing Record 29 of Set 2 | narsaq
# Processing Record 30 of Set 2 | muros
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | talcahuano
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 2 | harnosand
# Processing Record 36 of Set 2 | tsabong
# Processing Record 37 of Set 2 | carutapera
# Processing Record 38 of Set 2 | adeje
# Processing Record 39 of Set 2 | portobelo
# Processing Record 40 of Set 2 | ripky
# Processing Record 41 of Set 2 | port hawkesbury
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | andenes
# Processing Record 44 of Set 2 | iranshahr
# Processing Record 45 of Set 2 | derzhavinsk
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | aksu
# Processing Record 48 of Set 2 | durban
# Processing Record 49 of Set 2 | najran
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | vuktyl
# Processing Record 2 of Set 3 | cidreira
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | tarko-sale
# Processing Record 5 of Set 3 | caldelas
# Processing Record 6 of Set 3 | bud
# Processing Record 7 of Set 3 | asyut
# Processing Record 8 of Set 3 | oranjemund
# Processing Record 9 of Set 3 | beloha
# Processing Record 10 of Set 3 | arraial do cabo
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | oktyabrskoye
# Processing Record 13 of Set 3 | port elizabeth
# Processing Record 14 of Set 3 | dovolnoye
# Processing Record 15 of Set 3 | pervomayskiy
# Processing Record 16 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 17 of Set 3 | sao filipe
# Processing Record 18 of Set 3 | quatre cocos
# Processing Record 19 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 3 | satipo
# Processing Record 21 of Set 3 | nanortalik
# Processing Record 22 of Set 3 | la uribe
# City not found. Skipping...
# Processing Record 23 of Set 3 | zemio
# Processing Record 24 of Set 3 | umm durman
# City not found. Skipping...
# Processing Record 25 of Set 3 | tias
# Processing Record 26 of Set 3 | rize
# Processing Record 27 of Set 3 | bell ville
# Processing Record 28 of Set 3 | itarema
# Processing Record 29 of Set 3 | saraland
# Processing Record 30 of Set 3 | dwarka
# Processing Record 31 of Set 3 | berbera
# Processing Record 32 of Set 3 | mbacke
# City not found. Skipping...
# Processing Record 33 of Set 3 | masindi
# Processing Record 34 of Set 3 | rundu
# Processing Record 35 of Set 3 | catamarca
# Processing Record 36 of Set 3 | kapoeta
# Processing Record 37 of Set 3 | saint-francois
# Processing Record 38 of Set 3 | yenagoa
# Processing Record 39 of Set 3 | kuryk
# Processing Record 40 of Set 3 | grand gaube
# Processing Record 41 of Set 3 | sambava
# Processing Record 42 of Set 3 | vredendal
# Processing Record 43 of Set 3 | fomboni
# Processing Record 44 of Set 3 | guarapari
# Processing Record 45 of Set 3 | saint anthony
# Processing Record 46 of Set 3 | porto novo
# Processing Record 47 of Set 3 | plettenberg bay
# Processing Record 48 of Set 3 | tocache
# Processing Record 49 of Set 3 | obigarm
# Processing Record 50 of Set 3 | grindavik
# Processing Record 1 of Set 4 | jiblah
# Processing Record 2 of Set 4 | mehamn
# Processing Record 3 of Set 4 | aksay
# Processing Record 4 of Set 4 | havelock
# Processing Record 5 of Set 4 | vozhd proletariata
# City not found. Skipping...
# Processing Record 6 of Set 4 | forecariah
# Processing Record 7 of Set 4 | dujuma
# City not found. Skipping...
# Processing Record 8 of Set 4 | maunabo
# Processing Record 9 of Set 4 | iskateley
# Processing Record 10 of Set 4 | quepos
# Processing Record 11 of Set 4 | warrington
# Processing Record 12 of Set 4 | kulhudhuffushi
# Processing Record 13 of Set 4 | uwayl
# City not found. Skipping...
# Processing Record 14 of Set 4 | kristiinankaupunki
# Processing Record 15 of Set 4 | butembo
# Processing Record 16 of Set 4 | vieux-habitants
# Processing Record 17 of Set 4 | kuhdasht
# Processing Record 18 of Set 4 | koungheul
# Processing Record 19 of Set 4 | tessalit
# Processing Record 20 of Set 4 | cervo
# Processing Record 21 of Set 4 | ardistan
# City not found. Skipping...
# Processing Record 22 of Set 4 | aswan
# Processing Record 23 of Set 4 | mazagao
# Processing Record 24 of Set 4 | laguna
# Processing Record 25 of Set 4 | kargasok
# Processing Record 26 of Set 4 | marrakesh
# Processing Record 27 of Set 4 | emba
# Processing Record 28 of Set 4 | urumqi
# Processing Record 29 of Set 4 | kurdzhinovo
# Processing Record 30 of Set 4 | jaicos
# Processing Record 31 of Set 4 | mormugao
# Processing Record 32 of Set 4 | cape canaveral
# Processing Record 33 of Set 4 | klaksvik
# Processing Record 34 of Set 4 | bonavista
# Processing Record 35 of Set 4 | rio gallegos
# Processing Record 36 of Set 4 | sechura
# Processing Record 37 of Set 4 | usinsk
# Processing Record 38 of Set 4 | tobermory
# Processing Record 39 of Set 4 | port shepstone
# Processing Record 40 of Set 4 | ust-shonosha
# Processing Record 41 of Set 4 | saint-augustin
# Processing Record 42 of Set 4 | buraydah
# Processing Record 43 of Set 4 | inhambane
# Processing Record 44 of Set 4 | adrar
# Processing Record 45 of Set 4 | ilebo
# Processing Record 46 of Set 4 | cangucu
# Processing Record 47 of Set 4 | narragansett
# Processing Record 48 of Set 4 | springdale
# Processing Record 49 of Set 4 | kovdor
# Processing Record 50 of Set 4 | ibirite
# Processing Record 1 of Set 5 | preili
# Processing Record 2 of Set 5 | nouakchott
# Processing Record 3 of Set 5 | opuwo
# Processing Record 4 of Set 5 | nizhnevartovsk
# Processing Record 5 of Set 5 | ponta do sol
# Processing Record 6 of Set 5 | rota
# Processing Record 7 of Set 5 | pangody
# Processing Record 8 of Set 5 | dzilam gonzalez
# Processing Record 9 of Set 5 | itacurubi del rosario
# Processing Record 10 of Set 5 | oranjestad
# Processing Record 11 of Set 5 | leningradskiy
# Processing Record 12 of Set 5 | marsh harbour
# Processing Record 13 of Set 5 | key west
# Processing Record 14 of Set 5 | koslan
# Processing Record 15 of Set 5 | paita
# Processing Record 16 of Set 5 | humberto de campos
# Processing Record 17 of Set 5 | paragominas
# Processing Record 18 of Set 5 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 5 | ferrol
# Processing Record 20 of Set 5 | vila velha
# Processing Record 21 of Set 5 | oil city
# Processing Record 22 of Set 5 | bengkulu
# Processing Record 23 of Set 5 | vieques
# Processing Record 24 of Set 5 | lundazi
# Processing Record 25 of Set 5 | pimentel
# Processing Record 26 of Set 5 | valparaiso
# Processing Record 27 of Set 5 | aiken
# Processing Record 28 of Set 5 | amot
# Processing Record 29 of Set 5 | rey bouba
# Processing Record 30 of Set 5 | marsa matruh
# Processing Record 31 of Set 5 | husavik
# Processing Record 32 of Set 5 | ypsonas
# Processing Record 33 of Set 5 | bahadurganj
# Processing Record 34 of Set 5 | araouane
# Processing Record 35 of Set 5 | general pico
# Processing Record 36 of Set 5 | olafsvik
# Processing Record 37 of Set 5 | zabol
# Processing Record 38 of Set 5 | hunza
# City not found. Skipping...
# Processing Record 39 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 5 | ongole
# Processing Record 41 of Set 5 | chapais
# Processing Record 42 of Set 5 | mezen
# Processing Record 43 of Set 5 | salalah
# Processing Record 44 of Set 5 | saint-pierre
# Processing Record 45 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 46 of Set 5 | westport
# Processing Record 47 of Set 5 | vestmannaeyjar
# Processing Record 48 of Set 5 | bati
# Processing Record 49 of Set 5 | comodoro rivadavia
# Processing Record 50 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | camapua
# Processing Record 3 of Set 6 | hofn
# Processing Record 4 of Set 6 | gerede
# Processing Record 5 of Set 6 | burshtyn
# Processing Record 6 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 6 | kavaratti
# Processing Record 8 of Set 6 | knysna
# Processing Record 9 of Set 6 | presidente epitacio
# Processing Record 10 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 6 | sokoni
# Processing Record 13 of Set 6 | bonn
# Processing Record 14 of Set 6 | oriximina
# Processing Record 15 of Set 6 | castro
# Processing Record 16 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 17 of Set 6 | ambilobe
# Processing Record 18 of Set 6 | elizabeth city
# Processing Record 19 of Set 6 | kondinskoye
# Processing Record 20 of Set 6 | batsfjord
# Processing Record 21 of Set 6 | zubtsov
# Processing Record 22 of Set 6 | veinticinco de mayo
# Processing Record 23 of Set 6 | imeni morozova
# Processing Record 24 of Set 6 | port-gentil
# Processing Record 25 of Set 6 | rorvik
# Processing Record 26 of Set 6 | lerwick
# Processing Record 27 of Set 6 | antoniny
# Processing Record 28 of Set 6 | baft
# Processing Record 29 of Set 6 | taltal
# Processing Record 30 of Set 6 | rocha
# Processing Record 31 of Set 6 | santa lucia
# Processing Record 32 of Set 6 | gat
# Processing Record 33 of Set 6 | straumen
# Processing Record 34 of Set 6 | urucuca
# Processing Record 35 of Set 6 | parabel
# Processing Record 36 of Set 6 | mogadishu
# Processing Record 37 of Set 6 | camaqua
# Processing Record 38 of Set 6 | bondo
# Processing Record 39 of Set 6 | nueve de julio
# Processing Record 40 of Set 6 | nizwa
# Processing Record 41 of Set 6 | monte carmelo
# Processing Record 42 of Set 6 | marv dasht
# City not found. Skipping...
# Processing Record 43 of Set 6 | santa marinella
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | skjervoy
# Processing Record 46 of Set 6 | abiy adi
# City not found. Skipping...
# Processing Record 47 of Set 6 | mwinilunga
# Processing Record 48 of Set 6 | nurota
# Processing Record 49 of Set 6 | ulundi
# Processing Record 50 of Set 6 | asha
# Processing Record 1 of Set 7 | kanniyakumari
# Processing Record 2 of Set 7 | dhar
# Processing Record 3 of Set 7 | keuruu
# Processing Record 4 of Set 7 | torit
# Processing Record 5 of Set 7 | talnakh
# Processing Record 6 of Set 7 | kolo
# Processing Record 7 of Set 7 | matara
# Processing Record 8 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 9 of Set 7 | turi-alliku
# City not found. Skipping...
# Processing Record 10 of Set 7 | miranda
# Processing Record 11 of Set 7 | issa
# Processing Record 12 of Set 7 | lebu
# Processing Record 13 of Set 7 | mbini
# Processing Record 14 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 15 of Set 7 | lethem
# Processing Record 16 of Set 7 | san ramon
# Processing Record 17 of Set 7 | honningsvag
# Processing Record 18 of Set 7 | tanout
# Processing Record 19 of Set 7 | qaqortoq
# Processing Record 20 of Set 7 | viedma
# Processing Record 21 of Set 7 | shu
# Processing Record 22 of Set 7 | qax
# Processing Record 23 of Set 7 | camacha
# Processing Record 24 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 7 | bulawayo
# Processing Record 26 of Set 7 | kukushtan
# Processing Record 27 of Set 7 | canutama
# Processing Record 28 of Set 7 | tabuk
# Processing Record 29 of Set 7 | arlit
# Processing Record 30 of Set 7 | keta
# Processing Record 31 of Set 7 | beira
# Processing Record 32 of Set 7 | lekoni
# Processing Record 33 of Set 7 | raga
# Processing Record 34 of Set 7 | paso de los toros
# Processing Record 35 of Set 7 | leh
# Processing Record 36 of Set 7 | balkhash
# Processing Record 37 of Set 7 | hambantota
# Processing Record 38 of Set 7 | praia
# Processing Record 39 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 7 | chornobay
# Processing Record 41 of Set 7 | sao miguel do tapuio
# Processing Record 42 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 43 of Set 7 | koygorodok
# Processing Record 44 of Set 7 | olinda
# Processing Record 45 of Set 7 | cutro
# Processing Record 46 of Set 7 | verkh-suetka
# Processing Record 47 of Set 7 | akkermanovka
# Processing Record 48 of Set 7 | gharb
# City not found. Skipping...
# Processing Record 49 of Set 7 | fiche
# Processing Record 50 of Set 7 | calhoun
# Processing Record 1 of Set 8 | rawson
# Processing Record 2 of Set 8 | henties bay
# Processing Record 3 of Set 8 | marawi
# Processing Record 4 of Set 8 | jalu
# Processing Record 5 of Set 8 | ulstrup
# Processing Record 6 of Set 8 | svetlyy
# Processing Record 7 of Set 8 | rabo de peixe
# Processing Record 8 of Set 8 | storsteinnes
# Processing Record 9 of Set 8 | new milford
# Processing Record 10 of Set 8 | takoradi
# Processing Record 11 of Set 8 | tazovskiy
# Processing Record 12 of Set 8 | krasnaya gora
# Processing Record 13 of Set 8 | montbrison
# Processing Record 14 of Set 8 | eyl
# Processing Record 15 of Set 8 | mangrol
# Processing Record 16 of Set 8 | soyo
# Processing Record 17 of Set 8 | turbat
# Processing Record 18 of Set 8 | manaure
# Processing Record 19 of Set 8 | la sarre
# Processing Record 20 of Set 8 | abeche
# Processing Record 21 of Set 8 | walvis bay
# Processing Record 22 of Set 8 | bull savanna
# Processing Record 23 of Set 8 | natal
# Processing Record 24 of Set 8 | stupino
# Processing Record 25 of Set 8 | road town
# Processing Record 26 of Set 8 | nizhniye sergi
# Processing Record 27 of Set 8 | shelburne
# Processing Record 28 of Set 8 | colares
# Processing Record 29 of Set 8 | ardesen
# Processing Record 30 of Set 8 | vila franca do campo
# Processing Record 31 of Set 8 | duz
# City not found. Skipping...
# Processing Record 32 of Set 8 | the valley
# Processing Record 33 of Set 8 | san andres
# Processing Record 34 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 8 | salisbury
# Processing Record 36 of Set 8 | vallenar
# Processing Record 37 of Set 8 | ust-kulom
# Processing Record 38 of Set 8 | bath
# Processing Record 39 of Set 8 | santa isabel do rio negro
# Processing Record 40 of Set 8 | nevers
# Processing Record 41 of Set 8 | sumbawanga
# Processing Record 42 of Set 8 | berlevag
# Processing Record 43 of Set 8 | khalkhal
# Processing Record 44 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 8 | debre zeyit
# Processing Record 46 of Set 8 | camiri
# Processing Record 47 of Set 8 | benguela
# Processing Record 48 of Set 8 | coquimbo
# Processing Record 49 of Set 8 | elliot lake
# Processing Record 50 of Set 8 | matagami
# Processing Record 1 of Set 9 | hamilton
# Processing Record 2 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 9 | gap
# Processing Record 4 of Set 9 | aripuana
# Processing Record 5 of Set 9 | souillac
# Processing Record 6 of Set 9 | brinkovskaya
# Processing Record 7 of Set 9 | kasongo
# Processing Record 8 of Set 9 | sokolo
# Processing Record 9 of Set 9 | leninskoye
# Processing Record 10 of Set 9 | turukhansk
# Processing Record 11 of Set 9 | atbasar
# Processing Record 12 of Set 9 | thinadhoo
# Processing Record 13 of Set 9 | saldanha
# Processing Record 14 of Set 9 | bardiyah
# Processing Record 15 of Set 9 | coari
# Processing Record 16 of Set 9 | sile
# Processing Record 17 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 19 of Set 9 | palaikastron
# Processing Record 20 of Set 9 | samandag
# Processing Record 21 of Set 9 | eenhana
# Processing Record 22 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 9 | cayenne
# Processing Record 24 of Set 9 | carikar
# City not found. Skipping...
# Processing Record 25 of Set 9 | gamba
# Processing Record 26 of Set 9 | moose factory
# Processing Record 27 of Set 9 | lokosovo
# Processing Record 28 of Set 9 | makueni
# Processing Record 29 of Set 9 | miraflores
# Processing Record 30 of Set 9 | abnub
# Processing Record 31 of Set 9 | goundam
# Processing Record 32 of Set 9 | tambacounda
# Processing Record 33 of Set 9 | flores
# Processing Record 34 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 9 | kutum
# Processing Record 36 of Set 9 | kudahuvadhoo
# Processing Record 37 of Set 9 | pemba
# Processing Record 38 of Set 9 | kjollefjord
# Processing Record 39 of Set 9 | turayf
# Processing Record 40 of Set 9 | rusape
# Processing Record 41 of Set 9 | dukhovshchina
# Processing Record 42 of Set 9 | northampton
# Processing Record 43 of Set 9 | kindu
# Processing Record 44 of Set 9 | buta
# Processing Record 45 of Set 9 | remanso
# Processing Record 46 of Set 9 | grootfontein
# Processing Record 47 of Set 9 | udomlya
# Processing Record 48 of Set 9 | roald
# Processing Record 49 of Set 9 | dunmore town
# Processing Record 50 of Set 9 | hobro
# Processing Record 1 of Set 10 | vagur
# Processing Record 2 of Set 10 | tshikapa
# Processing Record 3 of Set 10 | bludenz
# Processing Record 4 of Set 10 | joshimath
# Processing Record 5 of Set 10 | mayor pablo lagerenza
# Processing Record 6 of Set 10 | maceio
# Processing Record 7 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 8 of Set 10 | pohrebyshche
# Processing Record 9 of Set 10 | sao jose da coroa grande
# Processing Record 10 of Set 10 | korla
# Processing Record 11 of Set 10 | sarab
# Processing Record 12 of Set 10 | oussouye
# Processing Record 13 of Set 10 | skagen
# Processing Record 14 of Set 10 | bandarbeyla
# Processing Record 15 of Set 10 | machala
# Processing Record 16 of Set 10 | simitli
# Processing Record 17 of Set 10 | sao raimundo nonato
# Processing Record 18 of Set 10 | palora
# Processing Record 19 of Set 10 | atar
# Processing Record 20 of Set 10 | oksovskiy
# Processing Record 21 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 22 of Set 10 | houlton
# Processing Record 23 of Set 10 | ville-marie
# Processing Record 24 of Set 10 | meulaboh
# Processing Record 25 of Set 10 | zvishavane
# Processing Record 26 of Set 10 | tacna
# Processing Record 27 of Set 10 | rome
# Processing Record 28 of Set 10 | san marcos
# Processing Record 29 of Set 10 | karakol
# Processing Record 30 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 31 of Set 10 | gogrial
# Processing Record 32 of Set 10 | san carlos
# Processing Record 33 of Set 10 | keetmanshoop
# Processing Record 34 of Set 10 | nefteyugansk
# Processing Record 35 of Set 10 | praia da vitoria
# Processing Record 36 of Set 10 | strezhevoy
# Processing Record 37 of Set 10 | dogondoutchi
# Processing Record 38 of Set 10 | cap malheureux
# Processing Record 39 of Set 10 | aguimes
# Processing Record 40 of Set 10 | ouesso
# Processing Record 41 of Set 10 | manali
# Processing Record 42 of Set 10 | brae
# Processing Record 43 of Set 10 | riyadh
# Processing Record 44 of Set 10 | belyy yar
# Processing Record 45 of Set 10 | ouro preto do oeste
# Processing Record 46 of Set 10 | jumla
# Processing Record 47 of Set 10 | yanam
# Processing Record 48 of Set 10 | los llanos de aridane
# Processing Record 49 of Set 10 | santa ines
# Processing Record 50 of Set 10 | rio grande
# Processing Record 1 of Set 11 | boyle
# Processing Record 2 of Set 11 | dingle
# Processing Record 3 of Set 11 | escanaba
# Processing Record 4 of Set 11 | venado tuerto
# Processing Record 5 of Set 11 | tikrit
# Processing Record 6 of Set 11 | oksfjord
# Processing Record 7 of Set 11 | wegrow
# Processing Record 8 of Set 11 | serik
# Processing Record 9 of Set 11 | elbistan
# Processing Record 10 of Set 11 | havre-saint-pierre
# Processing Record 11 of Set 11 | mwense
# Processing Record 12 of Set 11 | blacksburg
# Processing Record 13 of Set 11 | maun
# Processing Record 14 of Set 11 | upata
# Processing Record 15 of Set 11 | aquiraz
# Processing Record 16 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 11 | shenkursk
# Processing Record 18 of Set 11 | oistins
# Processing Record 19 of Set 11 | adra
# Processing Record 20 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 21 of Set 11 | trairi
# Processing Record 22 of Set 11 | alekseyevka
# Processing Record 23 of Set 11 | carnarvon
# Processing Record 24 of Set 11 | abu kamal
# Processing Record 25 of Set 11 | surt
# Processing Record 26 of Set 11 | ilorin
# Processing Record 27 of Set 11 | tonj
# Processing Record 28 of Set 11 | filingue
# Processing Record 29 of Set 11 | michigan city
# Processing Record 30 of Set 11 | mandera
# Processing Record 31 of Set 11 | bedele
# Processing Record 32 of Set 11 | san carlos de bariloche
# Processing Record 33 of Set 11 | ancud
# Processing Record 34 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 35 of Set 11 | olonets
# Processing Record 36 of Set 11 | banda aceh
# Processing Record 37 of Set 11 | kachiry
# Processing Record 38 of Set 11 | alenquer
# Processing Record 39 of Set 11 | chincha alta
# Processing Record 40 of Set 11 | callaway
# Processing Record 41 of Set 11 | santa maria
# Processing Record 42 of Set 11 | lisala
# Processing Record 43 of Set 11 | yarim
# Processing Record 44 of Set 11 | hameenlinna
# Processing Record 45 of Set 11 | kharovsk
# Processing Record 46 of Set 11 | san rafael
# Processing Record 47 of Set 11 | acarau
# Processing Record 48 of Set 11 | kristianstad
# Processing Record 49 of Set 11 | bani
# Processing Record 50 of Set 11 | ust-tsilma
# Processing Record 1 of Set 12 | raahe
# Processing Record 2 of Set 12 | skibbereen
# Processing Record 3 of Set 12 | umarkot
# Processing Record 4 of Set 12 | lesnoy
# Processing Record 5 of Set 12 | haselunne
# Processing Record 6 of Set 12 | eisenerz
# Processing Record 7 of Set 12 | langres
# Processing Record 8 of Set 12 | grand-santi
# Processing Record 9 of Set 12 | marzuq
# Processing Record 10 of Set 12 | albany
# Processing Record 11 of Set 12 | teya
# Processing Record 12 of Set 12 | neuquen
# Processing Record 13 of Set 12 | kiruna
# Processing Record 14 of Set 12 | carauari
# Processing Record 15 of Set 12 | jalna
# Processing Record 16 of Set 12 | zaysan
# Processing Record 17 of Set 12 | cockburn town
# Processing Record 18 of Set 12 | chitungwiza
# Processing Record 19 of Set 12 | bardstown
# Processing Record 20 of Set 12 | liepaja
# Processing Record 21 of Set 12 | jaciara
# Processing Record 22 of Set 12 | spirovo
# Processing Record 23 of Set 12 | cabedelo
# Processing Record 24 of Set 12 | amapa
# Processing Record 25 of Set 12 | ano mera
# Processing Record 26 of Set 12 | chulym
# Processing Record 27 of Set 12 | mugur-aksy
# Processing Record 28 of Set 12 | carmarthen
# Processing Record 29 of Set 12 | puerto carreno
# Processing Record 30 of Set 12 | chicama
# Processing Record 31 of Set 12 | umm lajj
# Processing Record 32 of Set 12 | winneba
# Processing Record 33 of Set 12 | havoysund
# Processing Record 34 of Set 12 | voznesenye
# Processing Record 35 of Set 12 | saint-ambroise
# Processing Record 36 of Set 12 | muisne
# Processing Record 37 of Set 12 | chokwe
# Processing Record 38 of Set 12 | bauska
# Processing Record 39 of Set 12 | hualmay
# Processing Record 40 of Set 12 | awbari
# Processing Record 41 of Set 12 | curanilahue
# Processing Record 42 of Set 12 | imbituba
# Processing Record 43 of Set 12 | coihueco
# Processing Record 44 of Set 12 | puerto ayacucho
# Processing Record 45 of Set 12 | skalistyy
# City not found. Skipping...
# Processing Record 46 of Set 12 | chinhoyi
# Processing Record 47 of Set 12 | jacareacanga
# Processing Record 48 of Set 12 | boende
# Processing Record 49 of Set 12 | cartagena del chaira
# Processing Record 50 of Set 12 | manacapuru
# Processing Record 1 of Set 13 | santa isabel
# Processing Record 2 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 3 of Set 13 | huarmey
# Processing Record 4 of Set 13 | vercelli
# Processing Record 5 of Set 13 | gao
# Processing Record 6 of Set 13 | alta floresta
# Processing Record 7 of Set 13 | sioux lookout
# Processing Record 8 of Set 13 | san lorenzo
# Processing Record 9 of Set 13 | sfantu gheorghe
# Processing Record 10 of Set 13 | bardsir
# Processing Record 11 of Set 13 | mondlo
# Processing Record 12 of Set 13 | ayacucho
# Processing Record 13 of Set 13 | morant bay
# Processing Record 14 of Set 13 | bolshoye polpino
# City not found. Skipping...
# Processing Record 15 of Set 13 | tomsk
# Processing Record 16 of Set 13 | nexo
# Processing Record 17 of Set 13 | nargana
# Processing Record 18 of Set 13 | abalak
# Processing Record 19 of Set 13 | heilbron
# Processing Record 20 of Set 13 | kaka
# Processing Record 21 of Set 13 | baghdad
# Processing Record 22 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 23 of Set 13 | durres
# Processing Record 24 of Set 13 | hare bay
# Processing Record 25 of Set 13 | einbeck
# Processing Record 26 of Set 13 | wana
# Processing Record 27 of Set 13 | rockland
# Processing Record 28 of Set 13 | timon
# Processing Record 29 of Set 13 | wah
# Processing Record 30 of Set 13 | santiago del estero
# Processing Record 31 of Set 13 | las palmas
# Processing Record 32 of Set 13 | yashkul
# Processing Record 33 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 34 of Set 13 | kostino
# Processing Record 35 of Set 13 | santa rosa
# Processing Record 36 of Set 13 | laterza
# Processing Record 37 of Set 13 | colombo
# Processing Record 38 of Set 13 | severnoye
# Processing Record 39 of Set 13 | sistranda
# Processing Record 40 of Set 13 | lakota
# Processing Record 41 of Set 13 | tansen
# Processing Record 42 of Set 13 | nesna
# Processing Record 43 of Set 13 | tahta
# Processing Record 44 of Set 13 | arboletes
# Processing Record 45 of Set 13 | esmeraldas
# Processing Record 46 of Set 13 | faya
# Processing Record 47 of Set 13 | do gonbadan
# Processing Record 48 of Set 13 | milici
# Processing Record 49 of Set 13 | kangaatsiaq
# Processing Record 50 of Set 13 | pudozh
# Processing Record 1 of Set 14 | massillon
# Processing Record 2 of Set 14 | nayagarh
# Processing Record 3 of Set 14 | waddan
# Processing Record 4 of Set 14 | cochrane
# Processing Record 5 of Set 14 | moissac
# Processing Record 6 of Set 14 | monrovia
# Processing Record 7 of Set 14 | axim
# Processing Record 8 of Set 14 | santiago de chuco
# Processing Record 9 of Set 14 | morro agudo
# Processing Record 10 of Set 14 | karanja
# Processing Record 11 of Set 14 | bolshiye uki
# City not found. Skipping...
# Processing Record 12 of Set 14 | clonakilty
# Processing Record 13 of Set 14 | meybod
# Processing Record 14 of Set 14 | estelle
# Processing Record 15 of Set 14 | herat
# Processing Record 16 of Set 14 | nagireddipalle
# City not found. Skipping...
# Processing Record 17 of Set 14 | kulevcha
# Processing Record 18 of Set 14 | bonthe
# Processing Record 19 of Set 14 | zachagansk
# City not found. Skipping...
# Processing Record 20 of Set 14 | antofagasta
# Processing Record 21 of Set 14 | biltine
# Processing Record 22 of Set 14 | kralendijk
# Processing Record 23 of Set 14 | mizdah
# Processing Record 24 of Set 14 | beyneu
# Processing Record 25 of Set 14 | tres de maio
# Processing Record 26 of Set 14 | saint-michel-des-saints
# Processing Record 27 of Set 14 | mangai
# Processing Record 28 of Set 14 | sembe
# Processing Record 29 of Set 14 | vizinga
# Processing Record 30 of Set 14 | alta gracia
# Processing Record 31 of Set 14 | rio cuarto
# Processing Record 32 of Set 14 | pizarro
# Processing Record 33 of Set 14 | puerto ayora
# Processing Record 34 of Set 14 | hattiesburg
# Processing Record 35 of Set 14 | dzaoudzi
# Processing Record 36 of Set 14 | kismayo
# Processing Record 37 of Set 14 | aconibe
# Processing Record 38 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 14 | schmolln
# Processing Record 40 of Set 14 | remontnoye
# Processing Record 41 of Set 14 | farafangana
# Processing Record 42 of Set 14 | kannur
# Processing Record 43 of Set 14 | caravelas
# Processing Record 44 of Set 14 | aranos
# Processing Record 45 of Set 14 | napasar
# Processing Record 46 of Set 14 | ngerengere
# Processing Record 47 of Set 14 | agirish
# Processing Record 48 of Set 14 | simoes
# Processing Record 49 of Set 14 | limulunga
# Processing Record 50 of Set 14 | shahreza
# Processing Record 1 of Set 15 | talah
# City not found. Skipping...
# Processing Record 2 of Set 15 | mikkeli
# Processing Record 3 of Set 15 | mpika
# Processing Record 4 of Set 15 | doha
# Processing Record 5 of Set 15 | serenje
# Processing Record 6 of Set 15 | kamenka
# Processing Record 7 of Set 15 | nacala
# Processing Record 8 of Set 15 | virginia beach
# Processing Record 9 of Set 15 | demba
# Processing Record 10 of Set 15 | sao paulo de olivenca
# Processing Record 11 of Set 15 | camargo
# Processing Record 12 of Set 15 | santander
# Processing Record 13 of Set 15 | sinnamary
# Processing Record 14 of Set 15 | taoudenni
# Processing Record 15 of Set 15 | kobojango
# City not found. Skipping...
# Processing Record 16 of Set 15 | bilma
# Processing Record 17 of Set 15 | zhezkazgan
# Processing Record 18 of Set 15 | marsabit
# Processing Record 19 of Set 15 | altamira
# Processing Record 20 of Set 15 | pisco
# Processing Record 21 of Set 15 | goure
# Processing Record 22 of Set 15 | villaviciosa
# Processing Record 23 of Set 15 | krasnoselkup
# Processing Record 24 of Set 15 | nador
# Processing Record 25 of Set 15 | gurgan
# City not found. Skipping...
# Processing Record 26 of Set 15 | kurchum
# Processing Record 27 of Set 15 | ulcinj
# Processing Record 28 of Set 15 | la rioja
# Processing Record 29 of Set 15 | montigny-les-metz
# Processing Record 30 of Set 15 | shevchenkove
# Processing Record 31 of Set 15 | karlskrona
# Processing Record 32 of Set 15 | narayanpet
# Processing Record 33 of Set 15 | betul
# Processing Record 34 of Set 15 | pyaozerskiy
# Processing Record 35 of Set 15 | ovalle
# Processing Record 36 of Set 15 | tabas
# Processing Record 37 of Set 15 | orebro
# Processing Record 38 of Set 15 | saint-joseph
# Processing Record 39 of Set 15 | soubre
# Processing Record 40 of Set 15 | ugoofaaru
# Processing Record 41 of Set 15 | fort payne
# Processing Record 42 of Set 15 | gobabis
# Processing Record 43 of Set 15 | umtata
# Processing Record 44 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 45 of Set 15 | oudtshoorn
# Processing Record 46 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 15 | penzance
# Processing Record 48 of Set 15 | kuusamo
# Processing Record 49 of Set 15 | sorrento
# Processing Record 50 of Set 15 | eskisehir
# Processing Record 1 of Set 16 | port blair
# Processing Record 2 of Set 16 | lahij
# Processing Record 3 of Set 16 | bay roberts
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create the pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Masunga      BW -20.6246   27.4488     91.58        24           9
# 1  Saint-Philippe      RE -21.3585   55.7679     88.11        73          12
# 2       Coihaique      CL -45.5752  -72.0662     48.81        81           0
# 3    Kruisfontein      ZA -34.0033   24.7314     65.88        60         100
# 4      Codrington      AU -38.2667  141.9667     57.87        67         100
# 5           Lagoa      PT  39.0500  -27.9833     64.06        87         100
# 6            Lasa      IT  46.6166   10.7002     32.74        71          90
# 7        Victoria      HK  22.2855  114.1577     71.19        37          77
# 8        Hermanus      ZA -34.4187   19.2345     69.91        65         100
# 9         Iqaluit      CA  63.7506  -68.5145      1.13        77          75
#
#    Wind Speed Current Description                 Date
# 0       15.46           clear sky  2021-12-04 08:20:50
# 1       13.76          few clouds  2021-12-04 08:20:50
# 2        4.61           clear sky  2021-12-04 08:16:21
# 3       10.92     overcast clouds  2021-12-04 08:20:50
# 4       11.99     overcast clouds  2021-12-04 08:20:51
# 5       10.94     overcast clouds  2021-12-04 08:20:51
# 6        3.04     overcast clouds  2021-12-04 08:20:51
# 7        1.01       broken clouds  2021-12-04 08:16:02
# 8       17.43     overcast clouds  2021-12-04 08:20:52
# 9       18.99       broken clouds  2021-12-04 08:20:52

# %%
# Create output CSV
output_data_file = "WeatherPy_Database.csv"
# Export into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
